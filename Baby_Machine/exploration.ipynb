# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from torchvision import datasets
from torchvision.transforms import ToTensor

import numpy as np

import pandas as pd

# %%
# Load the dataset, convert to numeric, and print basic information
df = pd.read_csv("/Users/ebouvet/Desktop/Baby_Machine/TCGA_BLCA_logCPM.csv")
print(df.shape)
print(df.head())
print(df.dtypes)

df_numeric = df.apply(pd.to_numeric, errors='coerce')
# Out:
# (412, 29905)
#                      Unnamed: 0  ENSG00000000003.15  ENSG00000000005.6  \
# 0  TCGA-BT-A3PJ-01A-21R-A220-07            6.927360           0.000000
# 1  TCGA-DK-A6B2-01A-11R-A30C-07            8.403132           1.502874
# 2  TCGA-GV-A3QK-01B-11R-A23N-07            7.797306           0.000000
# 3  TCGA-DK-A2I6-01A-12R-A18C-07            6.124464           0.039428
# 4  TCGA-C4-A0F7-01A-11R-A084-07            6.182355           0.037484
#
#    ENSG00000000419.13  ENSG00000000457.14  ENSG00000000460.17  \
# 0            5.459977            3.007716            3.197495
# 1            5.280863            5.166997            6.505088
# 2            5.122460            4.216115            3.011063
# 3            5.672695            3.330543            3.067583
# 4            6.574998            3.773384            4.570199
#
#    ENSG00000000938.13  ENSG00000000971.16  ENSG00000001036.14  \
# 0            3.537646            5.998143            6.854919
# ...

# %%
#creating a tensor from the numeric DataFrame
data_tensor = torch.tensor(df_numeric.values, dtype=torch.float32)
print(data_tensor.shape)
# Out:
# torch.Size([412, 29905])

# %%
from torch.utils.data import Dataset, DataLoader
class TensorDataset(Dataset):
    def __init__(self, data_tensor, labels_tensor=None):
        self.data_tensor = data_tensor
        self.labels_tensor = labels_tensor  
    def __len__(self):
        return self.data_tensor.size(0)

    def __getitem__(self, idx):
        if self.labels_tensor is not None:
            return self.data_tensor[idx], self.labels_tensor[idx]
        return self.data_tensor[idx]
dataset = TensorDataset(data_tensor)
data_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
model.train()
for inputs, targets in dataloader:
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    print(f"Loss: {loss.item():.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 model.train()
#       2 for inputs, targets in dataloader:
#       3     optimizer.zero_grad()
#
# NameError: name 'model' is not defined
